# %% [markdown]
# Here, I set to mark areas of the breast ultrasound scans that are cancerous using image segmentation with deep learning. To this goal, I designed a UNet architecture from scratch (in pytorch) which yielded a strong performance measured by Dice index.
#
# **Dice index was around 70% when averaged over test data samples.**
# <br><br>
# The analysis steps:
# * Import libraries
# * Collect data path for images
# * Load a subset of data to estimate mean and std for normalization purposes
# * Use the mean and std to create image transforms/augmentations
# * Separately load data samples into train and test sets
# * Visual inspection of data
# * Design the UNet
# * Instantiate a UNet
# * Train the model
# * Visualize model performance across epochs
# * Save the model
# * Visually inspect some of the segmentations in comparison to the ground truth
# * Check for potential biases in model performance across cancer types

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random

import torch
import torch.nn as nn
import torch.nn.functional as f
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from PIL import Image

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as T
from torchvision.io import read_image

import re
import matplotlib as mpl   
mpl.rcParams['font.family'] = ['sans-serif']
mpl.rcParams['font.sans-serif'] = ['SimHei']

data_path = 'Dataset_BUSI_with_GT'
from torch.autograd import Variable
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# # Collect image paths

# %%
image_list = []

folders = os.listdir(data_path)
for folder in folders:
    #if folder != 'normal':
    files = os.listdir( os.path.join(data_path, folder) )
    for file in files:
        if 'mask' not in file:
            image_list.append(data_path+'/'+folder+'/'+file) 

random.shuffle(image_list)

data_length = len( image_list )

image_list_train = image_list[:np.floor(0.7*data_length).astype(int)]
image_list_test = image_list[np.floor(0.3*data_length).astype(int):]

print( f'Total length of data: {data_length}')
# Out:
# Total length of data: 780

# %% [markdown]
# # define hyperparameters

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 64
CHANNEL_LIST = [1, 16, 32, 64]

N_EPOCHS = 60

class_to_inx = {'normal':0,'benign': 1, 'malignant': 2}
inx_to_class = {0:'normal',1: 'benign', 2: 'malignant'}
inx_to_class_ch = {0 :'无结节',1: '良性结节', 2: '恶性结节'}

# %% [markdown]
# # Define Data class

# %%
class BreastData(Dataset):
    def __init__(self, image_list, data_mode='Train', transform=None):
        self.image_list = image_list
        self.data_mode = data_mode
        self.image_transform = transform[0]
        self.mask_transform = transform[1]
        
    def __len__(self):
        return len(self.image_list)
    
    def extract_cancer_type(self, image_path):
        if 'benign' in image_path:
            cancer_type = 1
        elif 'malignant' in image_path:
            cancer_type = 2
        elif 'normal' in image_path:
            cancer_type = 0
        return cancer_type
    
    def __getitem__(self, index):
        image_path = self.image_list[index]
        image = Image.open(image_path).convert('RGB')
        
        mask_path = image_path.split('.')[0] + '_mask.png'
        mask = Image.open(mask_path).convert('1')
        
        image = self.image_transform(image)
        mask = self.mask_transform(mask)

        cancer_type = self.extract_cancer_type(image_path)
        return image, mask, cancer_type

# %% [markdown]
# # Define Tversky loss as a performance metric

# %%
class tverskyloss(nn.Module):
    def __init__(self, alpha=0.5, beta=0.5, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.beta = beta
        self.reduction = reduction
        
    def forward(self, pred, target):
        loss = 1 - tversky_index(pred, target, alpha=self.alpha, beta=self.beta, reduction=self.reduction)
        return loss

def tversky_index(y_pred, y_true, alpha=0.5, beta=0.5, reduction='mean'):
    # generalization of dice coefficient algorithm
    #   alpha corresponds to emphasis on False Positives
    #   beta corresponds to emphasis on False Negatives (our focus)
    #   if alpha = beta = 0.5, then same as dice
    #   if alpha = beta = 1.0, then same as IoU/Jaccard
    smooth = 1e-5
    
    if y_true.ndim > 3:
        y_true_f = y_true.reshape(y_true.shape[0], -1)
        y_pred_f = y_pred.reshape(y_pred.shape[0], -1)
    else:
        y_true_f = y_true.flatten()
        y_pred_f = y_pred.flatten()
        
    intersection = torch.sum(y_true_f * y_pred_f)
    tversky = (intersection + smooth) / ( intersection + alpha * (torch.sum(y_pred_f*(1 - y_true_f))) + beta *  (torch.sum((1 - y_pred_f)*y_true_f)) + smooth)
    
    if reduction == 'mean':
        tversky = tversky.mean()
    return tversky

# %% [markdown]
# # Define image transforms/augmentations

# %%
#basic transforms
image_transforms = {}

image_transforms['mask'] = T.Compose([
    T.Resize( int(np.floor(IMAGE_SIZE * 1.05)) ),
    T.ToTensor(),
    T.Grayscale(),
    T.CenterCrop(IMAGE_SIZE)
])

# %%
print(torch.__version__)
# Out:
# 2.0.1

# %%
# find mean and std for normalization purposes
transform = [image_transforms['mask'], image_transforms['mask']]
image_dataset = BreastData(image_list_train, transform=transform)
image_dataloader = torch.utils.data.DataLoader(image_dataset, batch_size=100, shuffle=True)
data_length = len(image_dataset)

# %%
subset = next(iter(image_dataloader))[0].permute(1, 0, 2, 3).reshape(1, -1)

mean = subset.mean(-1)
std = subset.std(-1)
print(f'Mean: {mean} --- std: {std}')
# Out:
# Mean: tensor([0.3385]) --- std: tensor([0.2174])

# %%
image_transforms['train'] = T.Compose([
    T.Resize( int(np.floor(IMAGE_SIZE * 1.05)) ),
    T.ToTensor(),
    T.Grayscale(),
    T.CenterCrop(IMAGE_SIZE),
    T.Normalize(mean=mean, std=std),
    T.RandomErasing(p=0.1, scale=(0.01, 0.1), ratio=(0.2, 5)),
])

image_transforms['test'] = T.Compose([
    T.Resize( int(np.floor(IMAGE_SIZE * 1.05)) ),
    T.ToTensor(),
    T.Grayscale(),
    T.CenterCrop(IMAGE_SIZE),
    T.Normalize(mean=mean, std=std),
])

# data augmentation 
image_transforms['original_complex'] = T.Compose([
    T.Resize( int(np.floor(IMAGE_SIZE * 1.05)) ),
    T.ToTensor(),
    T.ColorJitter(brightness=.1, hue=.1),
    T.Grayscale(),
    T.GaussianBlur(3,0.1),
    T.CenterCrop(IMAGE_SIZE),
    T.Normalize(mean=mean, std=std),
    T.RandomErasing(p=0.1, scale=(0.01, 0.1), ratio=(0.2, 5)),
])

# %% [markdown]
# # Split Image data into Train and Test sets

# %%
train_transform = [image_transforms['original_complex'], image_transforms['mask']]
#train_transform = [image_transforms['train'], image_transforms['mask']]
test_transform = [image_transforms['test'], image_transforms['mask']]

train_dataset = BreastData(image_list_train, transform=train_transform)
test_dataset = BreastData(image_list_test, transform=test_transform)

train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=BATCH_SIZE)
test_dataloader = DataLoader(test_dataset, shuffle=False, batch_size=BATCH_SIZE)

print(f'Train set size: {len(train_dataset)} ----- Test set size: {len(test_dataset)}')
# Out:
# Train set size: 546 ----- Test set size: 546

# %% [markdown]
# # Visual inspection of random data samples

# %%
images, masks, labels = next(iter(train_dataloader))
labels = np.array(labels)

fig, ax = plt.subplots(4,8, figsize=(20,12))
ax = ax.ravel()
for a in ax:
    a.axis('off')
    
for ind, (image, mask, label) in enumerate( zip(images, masks, labels) ):
    if ind < 16:
        plt.sca(ax[2 * ind])
        #plt.imshow(image.permute(1,2,0), cmap='gray')
        plt.imshow(image.permute(1,2,0))
        plt.title(f'乳腺超声图像 {inx_to_class_ch[label]}')
        #plt.title(f'#{ind+1}: {inx_to_class_ch[label]}')
        plt.sca(ax[2 * ind + 1])
        plt.imshow(mask.permute(1,2,0))
        #plt.title(f'#{ind+1} 结节区域')
        plt.title(f'结节区域')

# %% [markdown]
# # design the attention-based UNet, which learned from the pictures

# %%
#序列化地使用两种注意力机制，要比并行化使用效果要好。先使用通道注意力在实际数据对比上要优于先使用空间注意力
class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        #平均池化
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        #最大池化
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        
        #MLP  除以16是降维系数
        self.fc1   = nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False) #kernel_size=1
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        #结果相加
        out = avg_out + max_out
        return self.sigmoid(out)

#空间注意力
class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        #声明卷积核为 3 或 7
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        #进行相应的same padding填充
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)  #平均池化
        max_out, _ = torch.max(x, dim=1, keepdim=True) #最大池化
        #拼接操作
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x) #7x7卷积填充为3，输入通道为2，输出通道为1
        return self.sigmoid(x)

class CBAMLayer(nn.Module):
    def __init__(self, channel, reduction=16, spatial_kernel=7):
        super(CBAMLayer, self).__init__()
 
        # channel attention 压缩H,W为1
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
 
        # shared MLP
        self.mlp = nn.Sequential(
            # Conv2d比Linear方便操作
            # nn.Linear(channel, channel // reduction, bias=False)
            nn.Conv2d(channel, channel // reduction, 1, bias=False),
            # inplace=True直接替换，节省内存
            nn.ReLU(inplace=True),
            # nn.Linear(channel // reduction, channel,bias=False)
            nn.Conv2d(channel // reduction, channel, 1, bias=False)
        )
 
        # spatial attention
        self.conv = nn.Conv2d(2, 1, kernel_size=spatial_kernel,
                              padding=spatial_kernel // 2, bias=False)
        self.sigmoid = nn.Sigmoid()
 
    def forward(self, x):
        max_out = self.mlp(self.max_pool(x))
        avg_out = self.mlp(self.avg_pool(x))
        channel_out = self.sigmoid(max_out + avg_out)
        x = channel_out * x
 
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        avg_out = torch.mean(x, dim=1, keepdim=True)
        spatial_out = self.sigmoid(self.conv(torch.cat([max_out, avg_out], dim=1)))
        x = spatial_out * x
        return x

# %%
class unet(nn.Module):
    def __init__(self, CHANNEL_LIST):
        super().__init__()
        self.encoder_block = encoder(CHANNEL_LIST[:-1]) # 128 channels
        self.flat_block = conv_block(CHANNEL_LIST[-2], CHANNEL_LIST[-1]) # 256 channels
        self.bottle_block = CBAMLayer(64)
        self.decoder_block = decoder(CHANNEL_LIST[::-1][:-1]) 
        self.output_block = conv_block(CHANNEL_LIST[1], 1) 
        self.smooth_block = smooth_block() # filter small false positive results
        
    def forward(self, x):
        #print(x.shape)
        encoder_outputs, x = self.encoder_block(x)
        #print(x.shape)
        x = self.flat_block(x)
        #print(x.shape)
        x = self.bottle_block(x)
        x = self.decoder_block(x, encoder_outputs)
       # print(x.shape)
        x = self.output_block(x)
        x = f.sigmoid(self.smooth_block(x))
        
        return x    
        
class smooth_block(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = conv_block(1, 2, 5)  #maybe kernal size = 3 is better
        self.conv2 = conv_block(2, 1, 5)
        self.conv3 = conv_block(1, 2, 3)
        self.conv4 = conv_block(2, 1, 3)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        return x


class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernal=3):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernal, padding='same', bias=False)
        self.batchnorm1 = nn.BatchNorm2d(out_channels)        
        self.dropout = nn.Dropout2d(0.02)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernal, padding='same')
    
    def forward(self, x):
        x = self.dropout( f.relu( self.batchnorm1( self.conv1(x) ) ) )
        x = self.conv2(x)
        return x
    
    
class encoder(nn.Module):
    def __init__(self, channel_list):
        super().__init__()
        self.blocks = nn.ModuleList([
            conv_block(channel_list[i], channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
        self.maxpool = nn.MaxPool2d(2, 2)
    
    def forward(self, x):
        encoder_outputs = []
        for block in self.blocks:
            x = block(x)
            encoder_outputs.append(x)
            x = self.maxpool(x)
        return encoder_outputs, x
    
class decoder(nn.Module):
    def __init__(self, channel_list):
        super().__init__()
        self.upsamples = nn.ModuleList([
            nn.ConvTranspose2d(channel_list[i], channel_list[i+1], 2, 2)  
            for i in range(len(channel_list)-1)
        ])
        self.blocks = nn.ModuleList([
            conv_block(channel_list[i], channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
        self.attention_blocks = nn.ModuleList([
            CBAMLayer(channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
      
    
    def forward(self, x, encoder_outputs):
        encoder_outputs_reversed = encoder_outputs[::-1]

        for ind, (upsample, block, attention) in enumerate( zip(self.upsamples, self.blocks, self.attention_blocks) ):            
            x = upsample(x) # doubles the spatial dimension and decrease channels
            x = torch.cat([x, encoder_outputs_reversed[ind]], dim=1) # channels are increased again
            x = block(x) # decrease number of channels
            x = x + attention(x)
        return x
    
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.normal_(m.weight.data, 0, 0.02)

# %% [markdown]
# # Instantiate the model

# %%
UNet = unet(CHANNEL_LIST).to(device)
initialize_weights(UNet)

criterion = tverskyloss(alpha=0.5, beta=0.5)

optimizer = optim.AdamW(UNet.parameters(), lr=0.01,weight_decay=0.001)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=1, factor=0.1)

# %% [markdown]
# # Train the model

# %%
train_losses = []
test_losses = []
train_metrics = []
test_metrics = []
lrs = []

for epoch in range(N_EPOCHS):
    UNet.train()
    
    current_lr = optimizer.state_dict()['param_groups'][0]['lr'] 
    lrs.append( current_lr )
    
    running_loss = 0
    running_metric = 0
    
    for (images, masks, _) in train_dataloader:
        images = images.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()
        output = UNet(images)
        
        # loss 
        loss = criterion(output, masks)
        running_loss += loss.item() * images.shape[0]
        
        # accuracy metric
        img1 = torch.where(output.detach().cpu() >= 0.5, 1, 0)
        img2 = masks.detach().cpu()
        running_metric = running_metric + tversky_index(img1, img2) * images.shape[0]

        loss.backward()
        optimizer.step()
        
    lr_scheduler.step( running_loss )

    train_losses.append( running_loss / len(train_dataset) )
    train_metrics.append( running_metric / len(train_dataset) * 100 )
    

    with torch.no_grad():
        UNet.eval()
        
        running_loss = 0
        running_metric = 0
        for (images, masks, _) in test_dataloader:
            images = images.to(device)
            masks = masks.to(device)
        
            output = UNet(images)
            
            # loss
            loss = criterion(output, masks)
            running_loss += loss.item() * images.shape[0]
        
            # accuracy metric
            img1 = torch.where(output.detach().cpu() >= 0.5, 1, 0)
            img2 = masks.detach().cpu()
            running_metric = running_metric + tversky_index(img1, img2) * images.shape[0]
        
        test_losses.append( running_loss / len(test_dataset) )
        test_metrics.append( running_metric / len(test_dataset) * 100 )
        
    print(f'[{epoch+1}/{N_EPOCHS}]: train_loss={train_losses[-1]:0.2f} / test_loss={test_losses[-1]:0.2f} -------------  train_tversky={train_metrics[-1]:0.2f} / test_tversky={test_metrics[-1]:0.2f} -------------  lr={current_lr:0.8f}')
# Out:
# [1/150]: train_loss=0.79 / test_loss=0.78 -------------  train_tversky=22.65 / test_tversky=22.91 -------------  lr=0.10000000
# [2/150]: train_loss=0.72 / test_loss=0.76 -------------  train_tversky=28.63 / test_tversky=24.34 -------------  lr=0.10000000
# [3/150]: train_loss=0.71 / test_loss=0.76 -------------  train_tversky=28.91 / test_tversky=24.26 -------------  lr=0.10000000
# [4/150]: train_loss=0.66 / test_loss=0.68 -------------  train_tversky=34.37 / test_tversky=35.33 -------------  lr=0.10000000
# [5/150]: train_loss=0.65 / test_loss=0.65 -------------  train_tversky=35.52 / test_tversky=35.38 -------------  lr=0.10000000
# [6/150]: train_loss=0.63 / test_loss=0.58 -------------  train_tversky=36.73 / test_tversky=41.72 -------------  lr=0.10000000
# [7/150]: train_loss=0.62 / test_loss=0.60 -------------  train_tversky=37.87 / test_tversky=40.19 -------------  lr=0.10000000
# [8/150]: train_loss=0.60 / test_loss=0.81 -------------  train_tversky=39.67 / test_tversky=19.35 -------------  lr=0.10000000
# [9/150]: train_loss=0.60 / test_loss=0.58 -------------  train_tversky=40.50 / test_tversky=42.00 -------------  lr=0.10000000
# [10/150]: train_loss=0.63 / test_loss=0.68 -------------  train_tversky=36.90 / test_tversky=32.21 -------------  lr=0.10000000
# [11/150]: train_loss=0.59 / test_loss=0.55 -------------  train_tversky=41.09 / test_tversky=44.71 -------------  lr=0.10000000
# [12/150]: train_loss=0.59 / test_loss=0.58 -------------  train_tversky=40.62 / test_tversky=42.53 -------------  lr=0.10000000
# [13/150]: train_loss=0.57 / test_loss=0.56 -------------  train_tversky=42.97 / test_tversky=44.28 -------------  lr=0.10000000
# [14/150]: train_loss=0.57 / test_loss=0.80 -------------  train_tversky=43.46 / test_tversky=20.39 -------------  lr=0.10000000
# [15/150]: train_loss=0.58 / test_loss=0.55 -------------  train_tversky=41.72 / test_tversky=45.01 -------------  lr=0.10000000
# [16/150]: train_loss=0.56 / test_loss=0.56 -------------  train_tversky=43.67 / test_tversky=43.70 -------------  lr=0.10000000
# [17/150]: train_loss=0.56 / test_loss=0.61 -------------  train_tversky=44.12 / test_tversky=39.13 -------------  lr=0.10000000
# [18/150]: train_loss=0.55 / test_loss=0.56 -------------  train_tversky=45.44 / test_tversky=44.43 -------------  lr=0.10000000
# [19/150]: train_loss=0.56 / test_loss=0.54 -------------  train_tversky=44.22 / test_tversky=46.41 -------------  lr=0.10000000
# [20/150]: train_loss=0.55 / test_loss=0.49 -------------  train_tversky=45.44 / test_tversky=50.78 -------------  lr=0.10000000
# [21/150]: train_loss=0.54 / test_loss=0.47 -------------  train_tversky=46.28 / test_tversky=52.94 -------------  lr=0.10000000
# [22/150]: train_loss=0.55 / test_loss=0.66 -------------  train_tversky=45.36 / test_tversky=33.55 -------------  lr=0.10000000
# [23/150]: train_loss=0.54 / test_loss=0.62 -------------  train_tversky=46.07 / test_tversky=37.99 -------------  lr=0.10000000
# [24/150]: train_loss=0.51 / test_loss=0.63 -------------  train_tversky=49.47 / test_tversky=37.17 -------------  lr=0.05000000
# [25/150]: train_loss=0.53 / test_loss=0.48 -------------  train_tversky=47.40 / test_tversky=52.01 -------------  lr=0.05000000
# [26/150]: train_loss=0.51 / test_loss=0.48 -------------  train_tversky=48.56 / test_tversky=51.70 -------------  lr=0.05000000
# [27/150]: train_loss=0.50 / test_loss=0.45 -------------  train_tversky=49.83 / test_tversky=55.27 -------------  lr=0.02500000
# [28/150]: train_loss=0.56 / test_loss=0.47 -------------  train_tversky=44.07 / test_tversky=52.63 -------------  lr=0.02500000
# [29/150]: train_loss=0.52 / test_loss=0.45 -------------  train_tversky=47.96 / test_tversky=55.17 -------------  lr=0.02500000
# [30/150]: train_loss=0.48 / test_loss=0.44 -------------  train_tversky=51.57 / test_tversky=56.44 -------------  lr=0.01250000
# [31/150]: train_loss=0.50 / test_loss=0.44 -------------  train_tversky=49.92 / test_tversky=56.26 -------------  lr=0.01250000
# [32/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=50.86 / test_tversky=56.33 -------------  lr=0.01250000
# [33/150]: train_loss=0.48 / test_loss=0.44 -------------  train_tversky=52.10 / test_tversky=56.52 -------------  lr=0.00625000
# [34/150]: train_loss=0.47 / test_loss=0.45 -------------  train_tversky=52.91 / test_tversky=55.24 -------------  lr=0.00625000
# [35/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=52.00 / test_tversky=56.56 -------------  lr=0.00625000
# [36/150]: train_loss=0.47 / test_loss=0.43 -------------  train_tversky=53.20 / test_tversky=56.61 -------------  lr=0.00625000
# [37/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=51.87 / test_tversky=56.89 -------------  lr=0.00625000
# [38/150]: train_loss=0.50 / test_loss=0.43 -------------  train_tversky=50.38 / test_tversky=57.11 -------------  lr=0.00625000
# [39/150]: train_loss=0.49 / test_loss=0.43 -------------  train_tversky=50.57 / test_tversky=56.88 -------------  lr=0.00312500
# [40/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=50.81 / test_tversky=55.69 -------------  lr=0.00312500
# [41/150]: train_loss=0.47 / test_loss=0.43 -------------  train_tversky=52.96 / test_tversky=56.92 -------------  lr=0.00156250
# [42/150]: train_loss=0.46 / test_loss=0.43 -------------  train_tversky=54.39 / test_tversky=57.10 -------------  lr=0.00156250
# [43/150]: train_loss=0.47 / test_loss=0.43 -------------  train_tversky=53.43 / test_tversky=56.74 -------------  lr=0.00156250
# [44/150]: train_loss=0.49 / test_loss=0.43 -------------  train_tversky=50.68 / test_tversky=56.99 -------------  lr=0.00156250
# [45/150]: train_loss=0.50 / test_loss=0.43 -------------  train_tversky=50.19 / test_tversky=56.92 -------------  lr=0.00078125
# [46/150]: train_loss=0.51 / test_loss=0.45 -------------  train_tversky=48.84 / test_tversky=54.90 -------------  lr=0.00078125
# [47/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=51.77 / test_tversky=57.33 -------------  lr=0.00039063
# [48/150]: train_loss=0.50 / test_loss=0.45 -------------  train_tversky=50.15 / test_tversky=55.09 -------------  lr=0.00039063
# [49/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=52.48 / test_tversky=56.82 -------------  lr=0.00019531
# [50/150]: train_loss=0.54 / test_loss=0.43 -------------  train_tversky=46.50 / test_tversky=57.32 -------------  lr=0.00019531
# [51/150]: train_loss=0.54 / test_loss=0.43 -------------  train_tversky=46.45 / test_tversky=56.90 -------------  lr=0.00009766
# [52/150]: train_loss=0.52 / test_loss=0.45 -------------  train_tversky=48.42 / test_tversky=54.57 -------------  lr=0.00009766
# [53/150]: train_loss=0.51 / test_loss=0.43 -------------  train_tversky=49.28 / test_tversky=56.69 -------------  lr=0.00004883
# [54/150]: train_loss=0.51 / test_loss=0.43 -------------  train_tversky=48.72 / test_tversky=57.27 -------------  lr=0.00004883
# [55/150]: train_loss=0.51 / test_loss=0.43 -------------  train_tversky=49.51 / test_tversky=57.18 -------------  lr=0.00002441
# [56/150]: train_loss=0.49 / test_loss=0.46 -------------  train_tversky=51.19 / test_tversky=53.95 -------------  lr=0.00002441
# [57/150]: train_loss=0.51 / test_loss=0.46 -------------  train_tversky=48.54 / test_tversky=54.19 -------------  lr=0.00001221
# [58/150]: train_loss=0.52 / test_loss=0.45 -------------  train_tversky=47.63 / test_tversky=55.29 -------------  lr=0.00001221
# [59/150]: train_loss=0.49 / test_loss=0.45 -------------  train_tversky=51.08 / test_tversky=54.85 -------------  lr=0.00000610
# [60/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=51.03 / test_tversky=55.63 -------------  lr=0.00000610
# [61/150]: train_loss=0.52 / test_loss=0.43 -------------  train_tversky=48.16 / test_tversky=57.18 -------------  lr=0.00000305
# [62/150]: train_loss=0.47 / test_loss=0.43 -------------  train_tversky=52.87 / test_tversky=57.05 -------------  lr=0.00000305
# [63/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=50.89 / test_tversky=56.43 -------------  lr=0.00000153
# [64/150]: train_loss=0.51 / test_loss=0.43 -------------  train_tversky=48.57 / test_tversky=56.58 -------------  lr=0.00000153
# [65/150]: train_loss=0.51 / test_loss=0.44 -------------  train_tversky=49.02 / test_tversky=56.24 -------------  lr=0.00000076
# [66/150]: train_loss=0.51 / test_loss=0.44 -------------  train_tversky=49.28 / test_tversky=55.57 -------------  lr=0.00000076
# [67/150]: train_loss=0.50 / test_loss=0.43 -------------  train_tversky=49.68 / test_tversky=57.34 -------------  lr=0.00000038
# [68/150]: train_loss=0.46 / test_loss=0.47 -------------  train_tversky=53.67 / test_tversky=52.99 -------------  lr=0.00000038
# [69/150]: train_loss=0.53 / test_loss=0.45 -------------  train_tversky=47.13 / test_tversky=55.40 -------------  lr=0.00000019
# [70/150]: train_loss=0.53 / test_loss=0.47 -------------  train_tversky=46.66 / test_tversky=53.01 -------------  lr=0.00000019
# [71/150]: train_loss=0.53 / test_loss=0.43 -------------  train_tversky=47.50 / test_tversky=57.00 -------------  lr=0.00000010
# [72/150]: train_loss=0.46 / test_loss=0.43 -------------  train_tversky=54.11 / test_tversky=56.76 -------------  lr=0.00000010
# [73/150]: train_loss=0.56 / test_loss=0.43 -------------  train_tversky=44.07 / test_tversky=57.28 -------------  lr=0.00000005
# [74/150]: train_loss=0.50 / test_loss=0.43 -------------  train_tversky=50.28 / test_tversky=56.69 -------------  lr=0.00000005
# [75/150]: train_loss=0.46 / test_loss=0.43 -------------  train_tversky=54.31 / test_tversky=56.83 -------------  lr=0.00000002
# [76/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=50.65 / test_tversky=56.00 -------------  lr=0.00000002
# [77/150]: train_loss=0.51 / test_loss=0.45 -------------  train_tversky=48.95 / test_tversky=55.00 -------------  lr=0.00000001
# [78/150]: train_loss=0.51 / test_loss=0.43 -------------  train_tversky=49.01 / test_tversky=56.66 -------------  lr=0.00000001
# [79/150]: train_loss=0.50 / test_loss=0.44 -------------  train_tversky=50.01 / test_tversky=56.38 -------------  lr=0.00000001
# [80/150]: train_loss=0.52 / test_loss=0.43 -------------  train_tversky=47.73 / test_tversky=56.65 -------------  lr=0.00000001
# [81/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=51.56 / test_tversky=57.34 -------------  lr=0.00000001
# [82/150]: train_loss=0.50 / test_loss=0.45 -------------  train_tversky=49.60 / test_tversky=54.69 -------------  lr=0.00000001
# [83/150]: train_loss=0.49 / test_loss=0.44 -------------  train_tversky=50.57 / test_tversky=55.95 -------------  lr=0.00000001
# [84/150]: train_loss=0.52 / test_loss=0.43 -------------  train_tversky=47.86 / test_tversky=56.63 -------------  lr=0.00000001
# [85/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=51.58 / test_tversky=56.98 -------------  lr=0.00000001
# [86/150]: train_loss=0.48 / test_loss=0.43 -------------  train_tversky=52.41 / test_tversky=57.25 -------------  lr=0.00000001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[193], line 46
#      44 running_loss = 0
#      45 running_metric = 0
# ---> 46 for (images, masks, _) in test_dataloader:
#      47     images = images.to(device)
#      48     masks = masks.to(device)
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/utils/data/dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/utils/data/dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[6], line 22, in BreastData.__getitem__(self, index)
#      20 def __getitem__(self, index):
#      21     image_path = self.image_list[index]
# ---> 22     image = Image.open(image_path).convert('RGB')
#      24     mask_path = image_path.split('.')[0] + '_mask.png'
#      25     mask = Image.open(mask_path).convert('1')
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/PIL/Image.py:904, in Image.convert(self, mode, matrix, dither, palette, colors)
#     862 def convert(self, mode=None, matrix=None, dither=None, palette=WEB, colors=256):
#     863     """
#     864     Returns a converted copy of this image. For the "P" mode, this
#     865     method translates pixels through the palette.  If mode is
#    (...)
#     901     :returns: An :py:class:`~PIL.Image.Image` object.
#     902     """
# --> 904     self.load()
#     906     if not mode and self.mode == "P":
#     907         # determine default mode
#     908         if self.palette:
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/PIL/ImageFile.py:255, in ImageFile.load(self)
#     249         raise OSError(
#     250             "image file is truncated "
#     251             f"({len(b)} bytes not processed)"
#     252         )
#     254 b = b + s
# --> 255 n, err_code = decoder.decode(b)
#     256 if n < 0:
#     257     break
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualizer model performance across epochs

# %%
fig, ax = plt.subplots(3, 1, figsize=(8,12))
ax[0].plot(np.array(train_losses), marker='o', label='Train_loss')
ax[0].plot(np.array(test_losses), marker='o', label='Test_loss')
ax[0].legend()
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Losses')

ax[1].plot(np.array(train_metrics), marker='o', label='Train_metric')
ax[1].plot(np.array(test_metrics), marker='o', label='Test_metric')
ax[1].legend()
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Dice index')

ax[2].plot(np.array(lrs), marker='o', label='Train_accuracy')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Learning rate')
# Out:
# Text(0, 0.5, 'Learning rate')

# %% [markdown]
# # Save the model

# %%
torch.save(UNet, r'./saved/trained_model_UNet')

# %% [markdown]
# # Visually inspect segmentations

# %%
fig, ax = plt.subplots(4, 8, figsize=(22, 8))
for this_ax in ax.ravel():
    this_ax.axis('off')
    
for counter, ind in enumerate(np.random.choice(np.arange(len(test_dataset)), 8)):
    image, mask, cancer_type = test_dataset[ind]
    
    ax[0, counter].imshow( image.permute(1,2,0) )
    ax[0, counter].set_title('乳腺超声图像 '+inx_to_class_ch[cancer_type])
    
    ax[1, counter].imshow( mask.permute(1,2,0) )
    ax[1, counter].set_title('结节区域')

    segmentation = UNet(torch.unsqueeze(image, 0).to(device))
    ax[2, counter].imshow( torch.squeeze(segmentation.detach().cpu(), 0).permute(1,2,0) )
    ax[2, counter].set_title('结节预测区域 预测类型'+ inx_to_class_ch[cancer_type])
    
    segmentation = (segmentation.detach().cpu() > 0.5)
    ax[3, counter].imshow( torch.squeeze(segmentation, 0).permute(1,2,0) )
    ax[3, counter].set_title('结节预测区域 预测类型'+ inx_to_class_ch[cancer_type])

# %% [markdown]
# # Check for possible biases in model performance per cancer type

# %%
mask.shape

# %%
jaccard_index_per_type = {key: [] for key in class_to_inx.keys()}

for (image, mask, label) in test_dataset:
    image = torch.unsqueeze(image, 0).cpu()
    mask = torch.unsqueeze(mask, 0).cpu()
    UNet = UNet.cpu()
    segmentation = torch.where(UNet(image).detach() > 0.5, 1, 0)
    j = tversky_index(segmentation, mask)
    
    key = inx_to_class[label]
    jaccard_index_per_type[key].append( j )

jaccard_index_per_type = {key: np.array(val) for key, val in jaccard_index_per_type.items()}

# %%
for ind, (key, val) in enumerate(jaccard_index_per_type.items()):
    X = ind + np.random.randn(val.size) * 0.05
    plt.scatter(X, val, alpha=0.5)
    plt.plot([ind-0.2, ind+0.2], [val.mean(), val.mean()], linewidth=5)

plt.xlabel('Cancer type')
plt.ylabel('Jaccard index')

_ = plt.xticks(ticks=[0, 1], labels=jaccard_index_per_type.keys())
percentage = jaccard_index_per_type['benign'].mean() / jaccard_index_per_type['malignant'].mean() * 100

if percentage > 100:
    key_better = 'benign'
else:
    key_better = 'malignant'
percentage = abs( percentage - 100 )
print(f'Model performs better for class "{key_better}" by [{percentage:0.2f}] percent in Dice index.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 9
#       6 plt.xlabel('Cancer type')
#       7 plt.ylabel('Jaccard index')
# ----> 9 _ = plt.xticks(ticks=[0, 1], labels=jaccard_index_per_type.keys())
#      10 percentage = jaccard_index_per_type['benign'].mean() / jaccard_index_per_type['malignant'].mean() * 100
#      12 if percentage > 100:
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\matplotlib\pyplot.py:1893, in xticks(ticks, labels, minor, **kwargs)
#    1891         l._internal_update(kwargs)
#    1892 else:
# -> 1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1895 return locs, labels
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
#     293         since, message=f"The {old!r} parameter of {func.__name__}() "
#     294         f"has been renamed {new!r} since Matplotlib {since}; support "
#     295         f"for the old name will be dropped %(removal)s.")
#     296     kwargs[new] = kwargs.pop(old)
# --> 297 return func(*args, **kwargs)
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\matplotlib\axis.py:2018, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2014 if isinstance(locator, mticker.FixedLocator):
#    2015     # Passing [] as a list of labels is often used as a way to
#    2016     # remove all tick labels, so only error for > 0 labels
#    2017     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2018         raise ValueError(
#    2019             "The number of FixedLocator locations"
#    2020             f" ({len(locator.locs)}), usually from a call to"
#    2021             " set_ticks, does not match"
#    2022             f" the number of labels ({len(labels)}).")
#    2023     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2024     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of labels (3).

# %% [markdown]
# ## Train the classificationNet 2: The probability based model

# %%
class probabilityClassifyNet(nn.Module):
    def __init__(self, CHANNEL_LIST):
        super().__init__()
        self.encoder_block = encoder(CHANNEL_LIST[:-1]) # 128 channels
        self.flat_block = conv_block(CHANNEL_LIST[-2], 16)
        self.bottle_block = CBAMLayer(16)
        self.decoder_block = decoder(CHANNEL_LIST[::-1][:-1]) 
        self.output_block = conv_block(16, 1) 
        self.smooth_block = smooth_block()
        self.classify_block = classify_block2(256,3) 
        
    def forward(self, x):
        #print(x.shape)
        encoder_outputs, x = self.encoder_block(x)
        #print(x.shape)
        x = self.flat_block(x)
        #print(x.shape)
        xx = self.bottle_block(x)
        #print(x.shape)
        #x = self.decoder_block(x, encoder_outputs)
        #print(x.shape)
        x = self.output_block(x)
        #print(x.shape)
        x = self.smooth_block(x)
        x = self.classify_block(x,xx)

        return x    
        
class classify_block(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.node_decoder = nn.Sequential(
            nn.Dropout2d(0.02),nn.BatchNorm1d(256),nn.Linear(256, 1), nn.Sigmoid()
        )
        self.cancer_decoder = nn.Sequential(
           nn.Dropout2d(0.02),nn.BatchNorm1d(4096),nn.Linear(4096, 2),nn.Softmax()
        )
        self.out_put_size = out_channels
        self.softmax = nn.Softmax()
 

    def forward(self, segment,compressed):
        shape = segment.shape
        segment = segment.flatten(1,3)
        node_pro = self.node_decoder(segment)

        compressed = compressed.flatten(1,3)
        cancer_pro = self.cancer_decoder(compressed)

    
        # x = torch.cat((1-node_pro
        #                ,(1-cancer_pro)/node_pro, cancer_pro/node_pro), 1)
        
        x = torch.cat((1-node_pro
                       ,cancer_pro[:,0].view(-1,1)*node_pro, cancer_pro[:,1].view(-1,1)*node_pro), 1)
        return x

class classify_block2(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.node_decoder = nn.Sequential(
            nn.Dropout2d(0.02),nn.BatchNorm1d(256),nn.Linear(256, 1)
        )
        self.cancer_decoder = nn.Sequential(
           nn.Dropout2d(0.02),nn.BatchNorm1d(4096),nn.Linear(4096, 2)
        )
        self.out_put_size = out_channels
        self.softmax = nn.Softmax()
 

    def forward(self, segment,compressed):
        shape = segment.shape
        segment = segment.flatten(1,3)
        node_pro = self.node_decoder(segment)

        compressed = compressed.flatten(1,3)
        cancer_pro = self.cancer_decoder(compressed)

    
        # x = torch.cat((1-node_pro
        #                ,(1-cancer_pro)/node_pro, cancer_pro/node_pro), 1)
        
        x = self.softmax(torch.cat((node_pro,cancer_pro), 1))
        return x


class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernal=3):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernal, padding='same', bias=False)
        self.batchnorm1 = nn.BatchNorm2d(out_channels)        
        self.dropout = nn.Dropout2d(0.02)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernal, padding='same')
    
    def forward(self, x):
        x = self.dropout( f.relu( self.batchnorm1( self.conv1(x) ) ) )
        x = self.conv2(x)
        return x
    
    
class encoder(nn.Module):
    def __init__(self, channel_list):
        super().__init__()
        self.blocks = nn.ModuleList([
            conv_block(channel_list[i], channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
        self.maxpool = nn.MaxPool2d(2, 2)
    
    def forward(self, x):
        encoder_outputs = []
        for block in self.blocks:
            x = block(x)
            encoder_outputs.append(x)
            x = self.maxpool(x)
        return encoder_outputs, x
    
class decoder(nn.Module):
    def __init__(self, channel_list):
        super().__init__()
        self.upsamples = nn.ModuleList([
            nn.ConvTranspose2d(channel_list[i], channel_list[i+1], 2, 2)  
            for i in range(len(channel_list)-1)
        ])
        self.blocks = nn.ModuleList([
            conv_block(channel_list[i], channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
        self.attention_blocks = nn.ModuleList([
            CBAMLayer(channel_list[i+1])
            for i in range(len(channel_list)-1)
        ])
      
    
    def forward(self, x, encoder_outputs):
        encoder_outputs_reversed = encoder_outputs[::-1]

        for ind, (upsample, block, attention) in enumerate( zip(self.upsamples, self.blocks, self.attention_blocks) ):            
            x = upsample(x) # doubles the spatial dimension and decrease channels
            x = torch.cat([x, encoder_outputs_reversed[ind]], dim=1) # channels are increased again
            x = block(x) # decrease number of channels
            x = x + attention(x)
        return x
    
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.normal_(m.weight.data, 0, 0.02)
        if isinstance(m,nn.Linear):
            torch.nn.init.xavier_normal_(m.weight)

# %%
ClassprobabilityClassifyNetifyNet = probabilityClassifyNet(CHANNEL_LIST).to(device)
initialize_weights(ClassprobabilityClassifyNetifyNet)
criterion = nn.CrossEntropyLoss()

optimizer = optim.AdamW(ClassprobabilityClassifyNetifyNet.parameters(), lr=0.001,weight_decay=1)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=1, factor=0.5)

# %%
train_losses = []
test_losses = []
train_metrics = []
test_metrics = []
lrs = []

for epoch in range(N_EPOCHS):
   
    ClassprobabilityClassifyNetifyNet.train()
    
    current_lr = optimizer.state_dict()['param_groups'][0]['lr'] 
    lrs.append( current_lr )
    
    running_loss = 0
    running_metric = 0
    
    for (images, _, labels) in train_dataloader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        
        output = ClassprobabilityClassifyNetifyNet(images)
        
        #print(images.shape,output.shape,labels.shape)
        # loss 
        loss = criterion(output, labels)
        running_loss += loss.item() * images.shape[0]
        

        loss.backward()
        optimizer.step()
    print(output[0])
    lr_scheduler.step( running_loss )

    train_losses.append( running_loss / len(train_dataset) )


    with torch.no_grad():
        ClassprobabilityClassifyNetifyNet.eval()
        
        running_loss = 0
        running_metric = 0
        for (images, _, labels) in test_dataloader:
            images = images.to(device)
            labels = labels.to(device)
            
            output = ClassprobabilityClassifyNetifyNet(images)
            
        

            # loss
            loss = criterion(output, labels)
            running_loss += loss.item() * images.shape[0]
        
        
        test_losses.append( running_loss / len(test_dataset) )

    print(f'[{epoch+1}/{N_EPOCHS}]: train_loss={train_losses[-1]:0.2f} / test_loss={test_losses[-1]:0.2f}-------------  lr={current_lr:0.8f}')
# Out:
# /tmp/ipykernel_2646691/823518832.py:83: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.softmax(torch.cat((node_pro,cancer_pro), 1))
# tensor([0.0086, 0.9763, 0.0151], device='cuda:0', grad_fn=<SelectBackward0>)
# [1/60]: train_loss=0.77 / test_loss=0.80-------------  lr=0.00100000
# tensor([0.1991, 0.0671, 0.7338], device='cuda:0', grad_fn=<SelectBackward0>)
# [2/60]: train_loss=0.77 / test_loss=0.79-------------  lr=0.00100000
# tensor([0.0066, 0.9886, 0.0048], device='cuda:0', grad_fn=<SelectBackward0>)
# [3/60]: train_loss=0.77 / test_loss=0.79-------------  lr=0.00100000
# tensor([0.0261, 0.0087, 0.9652], device='cuda:0', grad_fn=<SelectBackward0>)
# [4/60]: train_loss=0.77 / test_loss=0.80-------------  lr=0.00100000
# tensor([0.0039, 0.9935, 0.0026], device='cuda:0', grad_fn=<SelectBackward0>)
# [5/60]: train_loss=0.75 / test_loss=0.77-------------  lr=0.00100000
# tensor([0.8649, 0.0634, 0.0718], device='cuda:0', grad_fn=<SelectBackward0>)
# [6/60]: train_loss=0.74 / test_loss=0.77-------------  lr=0.00100000
# tensor([1.6330e-04, 9.9982e-01, 1.7831e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [7/60]: train_loss=0.73 / test_loss=0.75-------------  lr=0.00100000
# tensor([0.5909, 0.1127, 0.2964], device='cuda:0', grad_fn=<SelectBackward0>)
# [8/60]: train_loss=0.73 / test_loss=0.75-------------  lr=0.00100000
# tensor([0.0061, 0.9919, 0.0021], device='cuda:0', grad_fn=<SelectBackward0>)
# [9/60]: train_loss=0.72 / test_loss=0.75-------------  lr=0.00100000
# tensor([0.0043, 0.0115, 0.9841], device='cuda:0', grad_fn=<SelectBackward0>)
# [10/60]: train_loss=0.70 / test_loss=0.74-------------  lr=0.00100000
# tensor([0.5399, 0.3587, 0.1014], device='cuda:0', grad_fn=<SelectBackward0>)
# [11/60]: train_loss=0.69 / test_loss=0.75-------------  lr=0.00100000
# tensor([0.0191, 0.8797, 0.1013], device='cuda:0', grad_fn=<SelectBackward0>)
# [12/60]: train_loss=0.71 / test_loss=0.73-------------  lr=0.00100000
# tensor([0.5262, 0.0325, 0.4414], device='cuda:0', grad_fn=<SelectBackward0>)
# [13/60]: train_loss=0.69 / test_loss=0.73-------------  lr=0.00100000
# tensor([0.0027, 0.9957, 0.0016], device='cuda:0', grad_fn=<SelectBackward0>)
# [14/60]: train_loss=0.68 / test_loss=0.73-------------  lr=0.00050000
# tensor([3.3626e-04, 9.9956e-01, 1.0402e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [15/60]: train_loss=0.67 / test_loss=0.71-------------  lr=0.00050000
# tensor([0.6607, 0.2662, 0.0731], device='cuda:0', grad_fn=<SelectBackward0>)
# [16/60]: train_loss=0.66 / test_loss=0.71-------------  lr=0.00050000
# tensor([0.0366, 0.4766, 0.4868], device='cuda:0', grad_fn=<SelectBackward0>)
# [17/60]: train_loss=0.67 / test_loss=0.71-------------  lr=0.00050000
# tensor([0.0973, 0.7463, 0.1564], device='cuda:0', grad_fn=<SelectBackward0>)
# [18/60]: train_loss=0.66 / test_loss=0.71-------------  lr=0.00050000
# tensor([0.0325, 0.9628, 0.0046], device='cuda:0', grad_fn=<SelectBackward0>)
# [19/60]: train_loss=0.65 / test_loss=0.70-------------  lr=0.00025000
# tensor([0.1123, 0.0651, 0.8226], device='cuda:0', grad_fn=<SelectBackward0>)
# [20/60]: train_loss=0.65 / test_loss=0.70-------------  lr=0.00025000
# tensor([7.9951e-04, 9.9786e-01, 1.3407e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [21/60]: train_loss=0.64 / test_loss=0.70-------------  lr=0.00025000
# tensor([0.5224, 0.2734, 0.2041], device='cuda:0', grad_fn=<SelectBackward0>)
# [22/60]: train_loss=0.63 / test_loss=0.70-------------  lr=0.00025000
# tensor([0.0057, 0.9497, 0.0446], device='cuda:0', grad_fn=<SelectBackward0>)
# [23/60]: train_loss=0.65 / test_loss=0.69-------------  lr=0.00025000
# tensor([0.1583, 0.8361, 0.0056], device='cuda:0', grad_fn=<SelectBackward0>)
# [24/60]: train_loss=0.65 / test_loss=0.70-------------  lr=0.00025000
# tensor([1.3062e-03, 9.9869e-01, 4.7613e-07], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [25/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00012500
# tensor([0.0053, 0.9848, 0.0099], device='cuda:0', grad_fn=<SelectBackward0>)
# [26/60]: train_loss=0.63 / test_loss=0.70-------------  lr=0.00012500
# tensor([1.3896e-02, 9.8604e-01, 5.9471e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [27/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00012500
# tensor([3.7627e-04, 9.7240e-01, 2.7225e-02], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [28/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00012500
# tensor([0.2769, 0.7222, 0.0009], device='cuda:0', grad_fn=<SelectBackward0>)
# [29/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00012500
# tensor([0.1123, 0.8298, 0.0579], device='cuda:0', grad_fn=<SelectBackward0>)
# [30/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00006250
# tensor([6.3474e-03, 9.9353e-01, 1.2262e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [31/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00006250
# tensor([0.0207, 0.9105, 0.0687], device='cuda:0', grad_fn=<SelectBackward0>)
# [32/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00006250
# tensor([1.2874e-03, 9.9862e-01, 8.8657e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [33/60]: train_loss=0.61 / test_loss=0.69-------------  lr=0.00006250
# tensor([0.3076, 0.5156, 0.1768], device='cuda:0', grad_fn=<SelectBackward0>)
# [34/60]: train_loss=0.61 / test_loss=0.69-------------  lr=0.00006250
# tensor([7.1990e-04, 9.9698e-01, 2.2992e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [35/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00006250
# tensor([0.5936, 0.0213, 0.3851], device='cuda:0', grad_fn=<SelectBackward0>)
# [36/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00003125
# tensor([0.2777, 0.5455, 0.1768], device='cuda:0', grad_fn=<SelectBackward0>)
# [37/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00003125
# tensor([0.6996, 0.0602, 0.2403], device='cuda:0', grad_fn=<SelectBackward0>)
# [38/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00001563
# tensor([0.3198, 0.6791, 0.0011], device='cuda:0', grad_fn=<SelectBackward0>)
# [39/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00001563
# tensor([0.0933, 0.3762, 0.5306], device='cuda:0', grad_fn=<SelectBackward0>)
# [40/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00000781
# tensor([0.1464, 0.7787, 0.0749], device='cuda:0', grad_fn=<SelectBackward0>)
# [41/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000781
# tensor([0.7692, 0.0410, 0.1898], device='cuda:0', grad_fn=<SelectBackward0>)
# [42/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000391
# tensor([0.0024, 0.9930, 0.0046], device='cuda:0', grad_fn=<SelectBackward0>)
# [43/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000391
# tensor([0.0081, 0.9792, 0.0127], device='cuda:0', grad_fn=<SelectBackward0>)
# [44/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000195
# tensor([1.6692e-02, 9.8330e-01, 4.7929e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [45/60]: train_loss=0.61 / test_loss=0.69-------------  lr=0.00000195
# tensor([0.7173, 0.1632, 0.1195], device='cuda:0', grad_fn=<SelectBackward0>)
# [46/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000195
# tensor([0.8710, 0.0154, 0.1136], device='cuda:0', grad_fn=<SelectBackward0>)
# [47/60]: train_loss=0.61 / test_loss=0.69-------------  lr=0.00000195
# tensor([1.8067e-02, 9.8183e-01, 1.0180e-04], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [48/60]: train_loss=0.61 / test_loss=0.69-------------  lr=0.00000098
# tensor([0.3821, 0.3437, 0.2742], device='cuda:0', grad_fn=<SelectBackward0>)
# [49/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000098
# tensor([0.0631, 0.0088, 0.9281], device='cuda:0', grad_fn=<SelectBackward0>)
# [50/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000049
# tensor([0.4721, 0.4252, 0.1027], device='cuda:0', grad_fn=<SelectBackward0>)
# [51/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000049
# tensor([0.4459, 0.5256, 0.0284], device='cuda:0', grad_fn=<SelectBackward0>)
# [52/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000024
# tensor([0.0132, 0.9819, 0.0048], device='cuda:0', grad_fn=<SelectBackward0>)
# [53/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000024
# tensor([4.3837e-03, 9.9561e-01, 5.3214e-06], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [54/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000012
# tensor([0.0219, 0.9622, 0.0159], device='cuda:0', grad_fn=<SelectBackward0>)
# [55/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000012
# tensor([0.0048, 0.1330, 0.8622], device='cuda:0', grad_fn=<SelectBackward0>)
# [56/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00000006
# tensor([0.1551, 0.1478, 0.6971], device='cuda:0', grad_fn=<SelectBackward0>)
# [57/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000006
# tensor([0.0037, 0.9774, 0.0189], device='cuda:0', grad_fn=<SelectBackward0>)
# [58/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000003
# tensor([0.0489, 0.8343, 0.1169], device='cuda:0', grad_fn=<SelectBackward0>)
# [59/60]: train_loss=0.63 / test_loss=0.69-------------  lr=0.00000003
# tensor([0.6591, 0.1690, 0.1719], device='cuda:0', grad_fn=<SelectBackward0>)
# [60/60]: train_loss=0.62 / test_loss=0.69-------------  lr=0.00000002

# %%
from sklearn.metrics import f1_score,confusion_matrix
is_node = []
is_node_label = []

is_cancer = []
is_cancer_label = []
full_test_dataloader = DataLoader(test_dataset, shuffle=False)

for images, _, labels in(full_test_dataloader):
    prob = ClassprobabilityClassifyNetifyNet(images.to(device)) #表示模型的预测输出
    prob = prob.cpu().detach().numpy() #先把prob转到CPU上，然后再转成numpy，如果本身在CPU上训练的话就不用先转成CPU了
    predict = np.argmax(prob,axis=1)
    for p in predict:
        if p !=0:p = 1
        else: p=0
        is_node.append(p) #求每一行的最大值索引
        
    for l in labels:
        if l !=0:
            l = 1
        is_node_label.append(l)
print("F1-Score:{:.4f}".format(f1_score(is_node_label,is_node)))
print(classification_report(is_node_label,is_node,labels=[0,1]))

print(confusion_matrix(is_node_label, is_node, labels=[0,1]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from sklearn.metrics import f1_score,confusion_matrix
#       2 is_node = []
#       3 is_node_label = []
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import accuracy_score, average_precision_score,precision_score,f1_score,recall_score,classification_report
predict = np.array([])
label = np.array([])

full_test_dataloader = DataLoader(test_dataset, shuffle=False)
for images, _, labels in(full_test_dataloader):
    prob = ClassprobabilityClassifyNetifyNet(images.to(device)) #表示模型的预测输出
    prob = prob.cpu().detach().numpy() #先把prob转到CPU上，然后再转成numpy，如果本身在CPU上训练的话就不用先转成CPU了
    _predict = np.argmax(prob,axis=1)

    predict = np.append(predict,_predict) #求每一行的最大值索引
    label=np.append(label,labels.cpu().detach().numpy())
    

print(label,'\n')
print(predict)

print('Micro precision', precision_score(label, predict, average='micro'))
print('Micro recall', recall_score(label, predict, average='micro'))
print("Micro F1-Score:{:.4f}".format(f1_score(label,predict,average='micro')))
print(classification_report(label,predict,labels=[0,1,2]))
print(confusion_matrix(label, predict, labels=[0,1,2]))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from sklearn.metrics import accuracy_score, average_precision_score,precision_score,f1_score,recall_score,classification_report
#       2 predict = np.array([])
#       3 label = np.array([])
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# # Visualizer model performance across epochs

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,12))
ax[0].plot(np.array(train_losses), marker='o', label='Train_loss')
ax[0].plot(np.array(test_losses), marker='o', label='Test_loss')
ax[0].legend()
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Losses')


ax[1].plot(np.array(lrs), marker='o', label='Train_accuracy')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Learning rate')

# %% [markdown]
# # Save model

# %%
torch.save(ClassprobabilityClassifyNetifyNet, r'./saved/trained_model_probabilityClassifyNet')
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[270], line 1
# ----> 1 torch.save(ClassprobabilityClassifyNetifyNet, r'./saved/trained_model_probabilityClassifyNet')
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439 if _use_new_zipfile_serialization:
#     440     with _open_zipfile_writer(f) as opened_zipfile:
# --> 441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#     443 else:
#
# File ~/anaconda3/envs/patent/lib/python3.8/site-packages/torch/serialization.py:653, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     651 pickler = pickle_module.Pickler(data_buf, protocol=pickle_protocol)
#     652 pickler.persistent_id = persistent_id
# --> 653 pickler.dump(obj)
#     654 data_value = data_buf.getvalue()
#     655 zip_file.write_record('data.pkl', data_value, len(data_value))
#
# PicklingError: Can't pickle <class '__main__.conv_block'>: it's not the same object as __main__.conv_block

# %% [markdown]
# # Visually inspect classification

# %%
images, masks, labels = next(iter(train_dataloader))
labels = np.array(labels)

fig, ax = plt.subplots(4,4, figsize=(20,12))
ax = ax.ravel()
for a in ax:
    a.axis('off')

def predict(model,img):
    model = model.eval()
    inx = model(img.to(device).view(1,1,64,64))
    inx = torch.argmax(inx).cpu()
    lable = inx_to_class_ch[int(inx)]
    return lable
    
for ind, (image, mask, label) in enumerate( zip(images, masks, labels) ):
    if ind < 16:
        plt.sca(ax[ind])
        plt.imshow(image.permute(1,2,0))
        plt.title(f'真实:{inx_to_class_ch[label]}  预测:{predict(ClassprobabilityClassifyNetifyNet,image)}')
# Out:
# /tmp/ipykernel_2646691/823518832.py:83: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.softmax(torch.cat((node_pro,cancer_pro), 1))

# %% [markdown]
# # fusion model

# %%
class fusionNet(nn.Module):
    def __init__(self, CHANNEL_LIST):
        super().__init__()
  
        self.fusion_block = fusion_block() 
        
    def forward(self, label, mask):
        label = self.fusion_block(mask, label)
        return label    


        
class fusion_block(nn.Module):
    def __init__(self, ):
        super().__init__()
  
        self.scale =  nn.Sequential(nn.BatchNorm1d(3),nn.Linear(3,256),nn.ReLU(), nn.Dropout2d(0.02),
                                    nn.BatchNorm1d(256),nn.Linear(256,256),nn.ReLU(),nn.Dropout2d(0.02),
                                    nn.BatchNorm1d(256),nn.Linear(256,256),nn.ReLU(),nn.Dropout2d(0.02),
                                    nn.BatchNorm1d(256),nn.Linear(256,2),nn.ReLU(),
                                   )
       
        self.img_decoder = nn.Sequential(
            nn.AdaptiveMaxPool2d(1)
                                   )
        
        self.sigmoid = nn.Sigmoid()
        self.softmax = nn.Softmax()
        self.apha1 = nn.Parameter(torch.tensor([1.0],device=device, ),requires_grad=True)
        self.apha2 = nn.Parameter(torch.tensor([1.0],device=device, ),requires_grad=True)
        self.apha3 = nn.Parameter(torch.tensor([1.0],device=device, ),requires_grad=True)
        self.register_parameter('apha1',self.apha1)
        self.register_parameter('apha2',self.apha2)
        self.register_parameter('apha3',self.apha3)
       

    def forward(self,mask,label):
        # if self.training:
        #     self.apha1.requires_grad=True
        #     self.apha2.requires_grad=True
        #     self.apha3.requires_grad=True
        # else:
        #     self.apha1.requires_grad=False
        #     self.apha2.requires_grad=False
        #     self.apha3.requires_grad=False
        
        label = label.view(-1,3)
        # mask = mask.view(-1,3,1)
        node_pro = self.img_decoder(mask).view(-1,1)
        caner_pro = self.scale(label).view(-1,2)
      
        x = self.softmax(torch.cat((1-node_pro, caner_pro[:,0].view(-1,1)*node_pro,caner_pro[:,1].view(-1,1)*node_pro), 1).view(-1,3))

        # # x = torch.where(x<0.5, 0, x)

        apha1 = self.sigmoid(self.apha1)
        apha2 = self.sigmoid(self.apha2)
        apha3 = self.sigmoid(self.apha3)

        # label = label + x
        
        # y1 = apha1*label[:,0].clone() 
        # y2 = apha2*label[:,1].clone().view(-1,1) + (1-apha2)*caner_pro[:,0].view(-1,1)*node_pro
        # y3 = apha3*label[:,2].clone().view(-1,1) + (1-apha3)*caner_pro[:,1].view(-1,1)*node_pro

        # test lost 0.50
        y1 = apha1*label[:,0].clone().view(-1,1) + (1-apha1)*x[:,0].view(-1,1)
        y2 = apha2*label[:,1].clone().view(-1,1) + (1-apha2)*x[:,1].view(-1,1)
        y3 = apha3*label[:,2].clone().view(-1,1) + (1-apha3)*x[:,2].view(-1,1)
        y1 = y1.view(-1,1)
        y2 = y2.view(-1,1)
        y3 = y3.view(-1,1)
        # print(y1.shape,y2.shape,y3.shape)
        y = torch.cat((y1,y2,y3), 1).view(-1,3)
        # y = torch.cat((y1,y2*(1-y1),y3*(1-y1)), 1).view(-1,3)
        y = self.softmax(y)
        return y


        
class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernal=3):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernal, padding='same', bias=False)
        self.batchnorm1 = nn.BatchNorm2d(out_channels)        
        self.dropout = nn.Dropout2d(0.02)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernal, padding='same')
    
    def forward(self, x):
        x = self.dropout( f.relu( self.batchnorm1( self.conv1(x) ) ) )
        x = self.conv2(x)
        return x
    
    
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.normal_(m.weight.data, 0, 0.02)
        if isinstance(m,nn.Linear):
            torch.nn.init.xavier_normal_(m.weight)

# %%
FusionNet = fusionNet(CHANNEL_LIST).to(device)
initialize_weights(FusionNet)
criterion = nn.CrossEntropyLoss()
# l = list([FusionNet.parameters()]+[FusionNet.fusion_block.apha1,FusionNet.fusion_block.apha2,FusionNet.fusion_block.apha3])
optimizer = optim.AdamW(FusionNet.parameters(), lr=0.001,weight_decay=1)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=1, factor=0.5)

# %%
train_losses = []
test_losses = []
train_metrics = []
test_metrics = []
lrs = []

for epoch in range(N_EPOCHS):
   
    FusionNet.train()
    
    current_lr = optimizer.state_dict()['param_groups'][0]['lr'] 
    lrs.append( current_lr )
    
    running_loss = 0
    running_metric = 0
    
    for (images, masks, labels) in train_dataloader:
        images = images.to(device)
        real_labels = labels.to(device)
        masks = masks.to(device)
        optimizer.zero_grad()

        labels = ClassprobabilityClassifyNetifyNet(images)
        masks = UNet(images)
        output = FusionNet(labels,masks)
        
        #print(images.shape,output.shape,labels.shape)
        # loss 
        loss = criterion(output, real_labels)
        running_loss += loss.item() * images.shape[0]
        

        loss.backward()
        optimizer.step()
    print(output[0])
    lr_scheduler.step( running_loss )

    train_losses.append( running_loss / len(train_dataset) )


    with torch.no_grad():
        FusionNet.eval()
        
        running_loss = 0
        running_metric = 0
        for (images, masks, labels) in test_dataloader:
            images = images.to(device)
            real_labels = labels.to(device)
            masks = masks.to(device)

            
            labels = ClassprobabilityClassifyNetifyNet(images)
            masks = UNet(images)
            output = FusionNet(labels,masks)
        
            
        

            # loss
            loss = criterion(output, real_labels)
            running_loss += loss.item() * images.shape[0]
        
        
        test_losses.append( running_loss / len(test_dataset) )

    print(f'[{epoch+1}/{N_EPOCHS}]: train_loss={train_losses[-1]:0.2f} / test_loss={test_losses[-1]:0.2f}-------------  lr={current_lr:0.8f}')
# Out:
# /tmp/ipykernel_2646691/823518832.py:83: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.softmax(torch.cat((node_pro,cancer_pro), 1))
# tensor([7.1487e-01, 2.9485e+00, 2.1956e-03], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [1/60]: train_loss=0.33 / test_loss=0.50-------------  lr=0.00100000
# tensor([4.3771e-03, 6.8277e-04, 4.4068e+00], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# [2/60]: train_loss=0.31 / test_loss=0.52-------------  lr=0.00100000
# tensor([0.0269, 0.6787, 1.0114], device='cuda:0', grad_fn=<SelectBackward0>)
# [3/60]: train_loss=0.30 / test_loss=0.51-------------  lr=0.00100000
# tensor([3.8808e-03, 4.9055e+00, 4.4637e-05], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
torch.save(FusionNet, r'./saved/trained_model_FusionNet')

# %%
FusionNet= torch.load( r'./saved/trained_model_FusionNet')

# %% [markdown]
# # load model

# %%
UNet= torch.load( r'./saved/trained_model_UNet')

# %%
ClassprobabilityClassifyNetifyNet = torch.load( r'./saved/trained_model_probabilityClassifyNet')

# %%
ClassifyNet= torch.load( r'./saved/trained_model_classifyNet')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[361], line 1
# ----> 1 ClassifyNet= torch.load( r'./saved/trained_model_classifyNet')
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\torch\serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\torch\serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1170 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1171 unpickler.persistent_load = persistent_load
# -> 1172 result = unpickler.load()
#    1174 torch._utils._validate_loaded_sparse_tensors()
#    1176 return result
#
# File D:\projects\Anaconda3\envs\patent\lib\site-packages\torch\serialization.py:1165, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1163         pass
#    1164 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1165 return super().find_class(mod_name, name)
#
# AttributeError: Can't get attribute 'classifyNet' on <module '__main__'>

# %% [markdown]
# #  Visual segmentation and classification

# %%
FusionNet.state_dict
# Out:
# <bound method Module.state_dict of fusionNet(
#   (fusion_block): fusion_block(
#     (scale): Sequential(
#       (0): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Linear(in_features=3, out_features=256, bias=True)
#       (2): ReLU()
#       (3): Dropout2d(p=0.02, inplace=False)
#       (4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Linear(in_features=256, out_features=256, bias=True)
#       (6): ReLU()
#       (7): Dropout2d(p=0.02, inplace=False)
#       (8): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Linear(in_features=256, out_features=256, bias=True)
#       (10): ReLU()
#       (11): Dropout2d(p=0.02, inplace=False)
#       (12): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (13): Linear(in_features=256, out_features=2, bias=True)
#       (14): ReLU()
#     )
#     (img_decoder): Sequential(
#       (0): AdaptiveMaxPool2d(output_size=1)
#     )
#     (sigmoid): Sigmoid()
#     (softmax): Softmax(dim=None)
#   )
# )>

# %%
FusionNet.fusion_block.apha1
# Out:
# Parameter containing:
# tensor([0.5443], device='cuda:0', requires_grad=True)

# %%
FusionNet.fusion_block.apha2
# Out:
# Parameter containing:
# tensor([0.7350], device='cuda:0', requires_grad=True)

# %%
FusionNet.fusion_block.apha3
# Out:
# Parameter containing:
# tensor([0.6997], device='cuda:0', requires_grad=True)

# %%
def predict(model,img,model2,mask):
    model2 = model2.eval()
    model = model.eval()
    label2 = model2(img.to(device).view(1,1,64,64))
    inx = model(label2.to(device).view(1,3),mask.to(device).view(1,1,64,64),)
    print(inx.detach().cpu(),label2.detach().cpu())
    inx = torch.argmax(inx).cpu()
    lable = inx_to_class_ch[int(inx)]
    return lable, inx_to_class_ch[int(torch.argmax(label2).cpu())]
    
fig, ax = plt.subplots(4, 6, figsize=(22, 16))
for this_ax in ax.ravel():
    this_ax.axis('off')

    
for counter, ind in enumerate(np.random.choice(np.arange(len(test_dataset)), 6)):
    image, mask, cancer_type = test_dataset[ind]
    
    ax[0, counter].imshow( image.permute(1,2,0) )
    ax[0, counter].set_title('真实结节类型: '+inx_to_class_ch[cancer_type])
    
    ax[1, counter].imshow( mask.permute(1,2,0) )
    ax[1, counter].set_title('真实结节区域')

    seg = UNet(torch.unsqueeze(image.to(device), 0))
    segmentation = (seg.detach().cpu() > 0.5)
    fussion_label, raw_label = predict(FusionNet,image,ClassprobabilityClassifyNetifyNet,seg)
    ax[2, counter].imshow( torch.squeeze(segmentation, 0).permute(1,2,0) )
    ax[2, counter].set_title('粗糙预测结节类型:'+raw_label +'\n预测结节区域')

    ax[3, counter].imshow( torch.squeeze(segmentation, 0).permute(1,2,0) )
    ax[3, counter].set_title('融合预测结节类型:'+fussion_label+'\n预测结节区域')

   

    #ax[5, counter].imshow(test_dataset[ind][0].permute(1,2,0) )
    #ax[5, counter].set_title('训练图像')
# Out:
# /tmp/ipykernel_2646691/823518832.py:83: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = self.softmax(torch.cat((node_pro,cancer_pro), 1))
# tensor([[0.4062, 0.0203, 0.0212]]) tensor([[0.9383, 0.0300, 0.0317]])
# tensor([[9.9811e-01, 3.9776e+00, 2.3479e-03]]) tensor([[0.0030, 0.9935, 0.0035]])
# tensor([[0.4802, 0.1153, 0.0054]]) tensor([[0.8213, 0.1706, 0.0081]])
# tensor([[0.9957, 3.9443, 0.0055]]) tensor([[0.0068, 0.9850, 0.0082]])
# tensor([[9.9740e-01, 4.0040e+00, 2.4726e-04]]) tensor([[4.1158e-03, 9.9551e-01, 3.7008e-04]])
# tensor([[9.9740e-01, 4.0040e+00, 2.4726e-04]]) tensor([[4.1158e-03, 9.9551e-01, 3.7008e-04]])
